# %% [markdown]
# **Header:**
#
# This files contains:
# 1. the answers to the questions given in `Assignment_problem_2024_Group2_Modified.mlx` (block by block) in order to have them in Markdown format for final reporting
# 2.  the results to `2024_Assignment Dynamics of Structures under Moving Loads Part B.pdf`

# %% [markdown]
# # 1 - Matlab Content
# ### Section: Create the mesh geometry of the two-layered beam
#
# The input parameters contained in `get_input_hyper_loop.m` are set to the following values:
# - total length of the track: 160 m
# - sleeper spacing: 16 m
# - element length: 1 m (obtained from Mesh Parameters, by division of *sleeper spacing* by *number of elements between springs*)
# - Young Modulus of sleeper: 74.6 GPa (from *Material Sleepers Data* parameters), which is marginally higher compared to common concrete material. #? This is meant to model the connection between the tubular structure and concrete supports.
#
# **Interpretation:**\
# The target model is:
#
# ![Model_Assignment](Figures/Scheme_Assignment.png)
#
# The matlab file `Assignment_problem_2024_Group2_Modified.mlx` implements the following structural scheme (from Canonical Problem 6):
#
# ![Model_CP6](Figures/Scheme_CP6.png)
#
# As such the following correspondence is found:
# |Component CP6| Hyperloop |
# |:-:|:-:|
# |Rail|Tubular Structure|
# |Sleepers| Concrete Supports (Mass) #? |
# |Railpad|(None)*|
# |Ballast**|Concrete Supports (Elasticity, Damping)**|
#
# \*modulus of elasticity is set to very high value, effectively eliminating the top layer of springs.
# <br>
# \*\*These components are rigidly fixed to the ground
#
# ### Section: Calculate and plot dispersion curves
# - #? Not sure how to determine the wavelength of each mode from 'modal shape spectrum plot. (Is this part of the exercise relevant to our assignment?)
#
# Expectation from modal shape graph in space (approximated values):
# - Purple: Mode 1, wavelength of 2L > 320 m
# - Yellow: Mode 2, wavelength of L > 160 m
# - Orange: Mode 3, wavelength of 2L/3 > 107 m
# - Blue: Mode 4, wavelength of  L/2 > 80 m
#
#
# ### Section: Exercises
# ##### Answer 1
# <div style="display: flex; justify-content: space-around; align-items: flex-start;">
#
#   <div style="text-align: center; margin: 10px;">
#     <img src="Figures/Plot_Dispersion_Lines.png" alt="Base Model" style="max-width: 100%; height: auto;">
#     <p style="margin-top: 5px; font-style: italic;">Base Model</p>
#   </div>
#
#   <div style="text-align: center; margin: 10px;">
#     <img src="Figures/Plot_Dispersion_Lines_Sleeper_RS.png" alt="Reduced Stiffness (Sleepers) Model" style="max-width: 100%; height: auto%;">
#     <p style="margin-top: 5px; font-style: italic;">Sleepers with reduced stiffness</p>
#   </div>
# </div>
# [To be completed]
#
# ##### Answer 2
#
# <div style="text-align: center; margin: 10px;">
#   <img src="Figures/Plot_Acc_Sleeper_RS.png" alt="Acceleration Plot (Reduced Stiffness Sleepers)" style="max-width: 100%; height: auto;">
#   <p style="margin-top: 5px; font-style: italic;">Reduced stiffness of sleepers: acceleration plot</p>
# </div>
#
# [To be completed]
#
# ##### Answer 3
# <div style="display: flex; justify-content: space-around; align-items: flex-start;">
#
#   <div style="text-align: center; margin: 10px;">
#     <img src="Figures/Plot_Dispersion_Lines.png" alt="Base Model" style="max-width: 100%; height: auto;">
#     <p style="margin-top: 5px; font-style: italic;">Base Model</p>
#   </div>
#
#   <div style="text-align: center; margin: 10px;">
#     <img src="Figures/Plot_Dispersion_Lines_Ballast_RS.png" alt="Half Stiffness Ballast Model" style="max-width: 100%; height: auto;">
#     <p style="margin-top: 5px; font-style: italic;">Ballast with half stiffness</p>
#   </div>
# </div>
#
# <div style="text-align: center; margin: 10px;">
#   <img src="Figures/Plot_Acc_Ballast_RS.png" alt="Acceleration Plot (Reduced Stiffness Ballast)" style="max-width: 100%; height: auto;">
#   <p style="margin-top: 5px; font-style: italic;">Reduced stiffness of balllast: acceleration plot</p>
# </div>
# [To be completed]
#
# ##### Answer 4
# <!-- <div style="display: flex; justify-content: space-around; align-items: flex-start;">
#
#   <div style="text-align: center; margin: 10px;">
#     <img src="Figures/Plot_Dispersion_Lines.png" alt="Base Model" style="max-width: 100%; height: auto;">
#     <p style="margin-top: 5px; font-style: italic;">Base Model</p>
#   </div>
#
#   <div style="text-align: center; margin: 10px;">
#     <img src="Figures/Plot_Dispersion_Lines_Pads_HS.png" alt="Higher Stiffness Model (Railpads)" style="max-width: 100%; height: auto;">
#     <p style="margin-top: 5px; font-style: italic;">Railpads with higher stiffness</p>
#   </div>
# </div> -->
#
# [To be completed]

# %% [markdown]
# # 2 - Assignment
#
# ### (Problem 2) Answer a
# <div style="text-align: center; margin: 10px;">
#   <img src="Figures/Plot_Dispersion_Lines.png" alt="Base Model" style="max-width: 100%; height: auto;">
#   <p style="margin-top: 5px; font-style: italic;">Base Model</p>
# </div>
# [To be completed]
#
# ### (Problem 2) Answer c
# [To be completed]

# %% [markdown]
# # Questions:
# **Model Setup**
# - What are sleepers modelling exactly? It's E modulus is not reflecting any of the given input parameters in the assignment.
#   R - The sleepers do correspond to the mass attached to the beam. The model should be completely setup, we can just run in and look into comparing with the ANSYS model
# - Are input parameters set correctly in the `get_input_hyper_loop.m` file?
#   - External Forces does not match given Dead Weight
#     R - The model should be completely setup, we can just run in and look into comparing with the ANSYS model
#   - Modulus of Elasticity of sleepers: there is extra coefficient 1.5?
#     R - The model should be completely setup, we can just run in and look into comparing with the ANSYS model
#   - Mass of sleeper does not match given Support Mass
#     R - The model should be completely setup, we can just run in and look into comparing with the ANSYS model
#   - From matlab plot it looks like the rail is not centered (this is reflected in the Mesh parameters, why do we do this?)
#     R - "That should not matter, the sleepers only provide vertical support"
#
# **Matlab file content**
# - How to read 'modal shape spectrum' graphs presented in the matlab script
#   R - Peaks correspond to the wavelength, we can zoom out for better readability. The purple curve is interrupted due to modelling parameters, but the peak should be at 320.
# - Are excercises at the bottom of `Assignment_problem_2024_Group2_Modified.mlx` to be carried out? They do not seem connected to our assignment
#   R - No, they are for student comprehension (not included in the assignment)
# - What is the difference between 'large scale' and 'small scale' Brillouin zones?
#
# **Exercises**
# - Question 2: Is this the correct acceleration plot? Should we infer the wavelength from this plot (periodicity is hard to see)
#   R - It is, the irregularity comes from "imperfections probably being included in the model". If we used a less stiff railpad we should be able to
# - Question 4: Isn't the current model already very stiff?
#   R - (A bit out of scope) If we lower the stiffness we expect the modal shapes to be more defined because the sleepers will 'absorb' the vibration.
#
# **PDF**
# - What sort of interpretation is to be given?
#   R - Description of stop-bands and critical speed, cutoff frequency. Qualitative description of the plot. The interesting part is the comparison with ansys
